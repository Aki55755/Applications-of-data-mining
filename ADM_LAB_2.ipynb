# %% [markdown]
# <a href="https://colab.research.google.com/github/Aki55755/Applications-of-data-mining/blob/main/ADM_LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Generate Statistical Summaries of the Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/titanic.csv')

# %%
summary_statistics = df.describe()
print(summary_statistics)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 2. Create Visualizations Using Matplotlib and Seaborn

# %% [markdown]
# # a.Histrogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# b. Bar Chart

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Survived', data=df)
plt.title('Survivor Count')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# c. Box Plot

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Survived', y='Fare', data=df)
plt.title('Fare Distribution by Survival')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# d. Pair Plot

# %%
sns.pairplot(df[['Survived', 'Pclass', 'Age', 'Fare']])
plt.title('Pair Plot of Selected Features')
plt.show()

# %% [markdown]
# e. Correlation Heatmap

# %%
numeric_df = df.select_dtypes(include=['number'])
plt.figure(figsize=(8, 5))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# f. Violin Plot

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Survived', y='Age', data=df, inner='quartile')
plt.title('Age Distribution by Survival')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# g. Count Plot

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title('Passenger Count by Class and Survival')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# h. Line Chart

# %%
average_fare = df.groupby('Pclass')['Fare'].mean().reset_index()
plt.figure(figsize=(8, 5))
sns.lineplot(x='Pclass', y='Fare', data=average_fare, marker='o')
plt.title('Average Fare by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Average Fare')
plt.show()
